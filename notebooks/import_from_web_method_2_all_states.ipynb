# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd

# %% [markdown]
# # import from website daily COVID-19 tracking for all states
# not using this datset for the project, only to show method of using beautiful soup to extract data

# %% [markdown]
# check for respnse

# %%
website_url = 'https://docs.google.com/spreadsheets/u/2/d/e/2PACX-1vRwAqp96T9sYYq2-i7Tj0pvTf6XVHjDSMIKBdZHXiCGGdNC0ypEU9NbngS8mxea55JuCFuua1MUeOj5/pubhtml#'
response = requests.get(website_url)

response.status_code
# Out:
# 200

# %% [markdown]
# ### check content

# %%
print(type(response))
#response.content
# Out:
# <class 'requests.models.Response'>

# %% [markdown]
# # Use Beautiful Soup package for extracting data

# %%
soup = BS(response.content, 'lxml')
print(soup.title)
# Out:
# <title>Coronavirus numbers by state - Google Drive</title>

# %% [markdown]
# ### Get the tables from the page

# %%
tables = soup.find_all('table', attrs = {'class': 'waffle'})
#tables

# %% [markdown]
# ### check number of tables extracted

# %%
len(tables)
# Out:
# 6

# %% [markdown]
# get the tables as dataframes

# %%
result_list = pd.read_html(str(tables[3]))
len(result_list)
# Out:
# 1

# %% [markdown]
# get the first dataframe from the list

# %%
covid_19_states = result_list[0]  # get the first df from the list

covid_19_states.columns = covid_19_states.iloc[0] #use first row as columns names

#covid_19_states.head(10)
# Out:
# 0  1.0      Date  State  Positive  Negative  Pending  \
# 0  1.0      Date  State  Positive  Negative  Pending
# 1  NaN       NaN    NaN       NaN       NaN      NaN
# 2  2.0  20200609     AK       573     66317      NaN
# 3  3.0  20200609     AL     21422    246317      NaN
# 4  4.0  20200609     AR     10080    155701      NaN
# 5  5.0  20200609     AS         0       174      NaN
# 6  6.0  20200609     AZ     28296    264917      NaN
# 7  7.0  20200609     CA    133489   2352756      NaN
# 8  8.0  20200609     CO     28183    193704      NaN
# 9  9.0  20200609     CT     44179    268472      NaN
#
# 0  Hospitalized – Currently  Hospitalized – Cumulative  In ICU – Currently  \
# 0  Hospitalized – Currently  Hospitalized – Cumulative  In ICU – Currently
# 1                       NaN                        NaN                 NaN
# 2                        12                        NaN                 NaN
# 3                       600                       2087                 NaN
# 4                       173                        865                 NaN
# 5                       NaN                        NaN                 NaN
# 6                      1243                       3406                 438
# 7                      4583                        NaN                1345
# 8                       304                       4859                 NaN
# 9                       293                       9669                 NaN
#
# 0  In ICU – Cumulative  On Ventilator – Currently  On Ventilator – Cumulative  \
# 0  In ICU – Cumulative  On Ventilator – Currently  On Ventilator – Cumulative
# 1                  NaN                        NaN                         NaN
# 2                  NaN                          1                         NaN
# 3                  631                        NaN                         375
# 4                  NaN                         44                         144
# 5                  NaN                        NaN                         NaN
# 6                  NaN                        264                         NaN
# 7                  NaN                        NaN                         NaN
# 8                  NaN                        NaN                         NaN
# 9                  NaN                        NaN                         NaN
#
# 0  Recovered  Deaths  Data Quality Grade  Last Update ET
# 0  Recovered  Deaths  Data Quality Grade  Last Update ET
# 1        NaN     NaN                 NaN             NaN
# 2        389      11                   A  6/9/2020 00:00
# 3      11395     729                   B  6/9/2020 11:00
# 4       6875     161                   A  6/9/2020 15:00
# 5        NaN       0                   C  6/1/2020 00:00
# 6       5764    1070                  A+  6/9/2020 00:00
# 7        NaN    4697                   B  6/9/2020 00:00
# 8       4112    1543                   A  6/9/2020 00:00
# 9       7284    4097                   B  6/8/2020 20:30

# %%
#not using this dataframe for the project, only shows another way of using beautiful soup extracting data
#create dataframe from the list
#df1=pd.DataFrame()
#df1=df1.append(pd.DataFrame(result_list[0]))
#df1.shape
# Out:
# (5395, 16)

# %%
 #df1.to_csv('..\data\covid_19_daily_update_allStates.csv', index= False)# save it to csv file

# %% [markdown]
# # import from website more tables on covid-19
# use this dataset for the project

# %%
df2 = pd.read_csv('https://covidtracking.com/api/v1/states/daily.csv')

# %%
df2.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200609    AK     573.0   66317.0      NaN                   12.0
# 1  20200609    AL   21422.0  246317.0      NaN                  600.0
# 2  20200609    AR   10080.0  155701.0      NaN                  173.0
# 3  20200609    AS       0.0     174.0      NaN                    NaN
# 4  20200609    AZ   28296.0  264917.0      NaN                 1243.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                  2087.0             NaN            631.0
# 2                   865.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                  3406.0           438.0              NaN
#
#    onVentilatorCurrently  ...  posNeg  deathIncrease hospitalizedIncrease  \
# 0                    1.0  ...   66890              1                    0
# 1                    NaN  ...  267739             11                   33
# 2                   44.0  ...  165781              6                   21
# 3                    NaN  ...     174              0                    0
# 4                  264.0  ...  293213             23                   29
#
#                                        hash commercialScore  \
# 0  9eaf1802a047fc56612f95b6e8221d463088d951               0
# 1  efc4ed6259393a9d1a456d534f048bed440a3188               0
# 2  851214658655b6d73de5bdcef6d60ff6f4cba91f               0
# 3  0df19625dbb3d07994abcf96f96cf424a01197f9               0
# 4  13e930e15aa12c07ffcf3af528334c67a01893a1               0
#
#   negativeRegularScore  negativeScore  positiveScore score  grade
# 0                    0              0              0     0    NaN
# 1                    0              0              0     0    NaN
# 2                    0              0              0     0    NaN
# 3                    0              0              0     0    NaN
# 4                    0              0              0     0    NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# Save it to csv file and continue to clean and explore in another notebook

# %%
#save to csv file, then use another notebook for cleaning and EDA, continue to the next notebook
df2.to_csv('..\data\covid_19_update_allStates_2.csv', index= False)

# %% [markdown]
# # import  counties

# %%
#this link includes counties, but it includes noly latest date aboute covid-19
#df3= pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv')

# %%
#this link includes counties with all dates since the begining of the pandamic
df3= pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv")

# %%
#df3 = df3.fillna(0)

# %%
#comment it out because we are going to change the data type in the final combined all dataframes in the join notebook
'''df3= df3.astype({  "fips": int,
                  "cases": int,
                'deaths' : int,
                                       
                 })        #convert columns data type to int'''

# %%
df3.head()
# Out:
#          date     county       state   fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061      1       0
# 1  2020-01-22  Snohomish  Washington  53061      1       0
# 2  2020-01-23  Snohomish  Washington  53061      1       0
# 3  2020-01-24       Cook    Illinois  17031      1       0
# 4  2020-01-24  Snohomish  Washington  53061      1       0

# %%
#save it as csv file and send join it in the join notebook 
df3.to_csv('..\data\covid_19_update_allStatesAndCounties_3.csv', index= False)

# %% [markdown]
# ## import states lockdown dates: start and end

# %% [markdown]
# 1- import date start of the lockdown from website

# %%
website_url = 'https://ballotpedia.org/Status_of_lockdown_and_stay-at-home_orders_in_response_to_the_coronavirus_(COVID-19)_pandemic,_2020'
response = requests.get(website_url)

response.status_code
# Out:
# 200

# %%
print(type(response))
#response.content
# Out:
# <class 'requests.models.Response'>

# %%
soup = BS(response.content, 'lxml')
print(soup.title)
# Out:
# <title>Status of lockdown and stay-at-home orders in response to the coronavirus (COVID-19) pandemic, 2020 - Ballotpedia</title>

# %%
url='https://ballotpedia.org/Status_of_lockdown_and_stay-at-home_orders_in_response_to_the_coronavirus_(COVID-19)_pandemic,_2020'

# %%
df_lockdown_start_date = pd.DataFrame()

response = requests.post(url)
soup = BS(response.text, 'lxml')
   
tables = soup.find_all('table',
                           attrs = {'class': 'marqueetable endorsements'})
result_list = pd.read_html(str(tables[0]))
#turn the list to datframe
df_lockdown_start_date = pd.DataFrame(result_list[0])

# %%
df_lockdown_start_date.head()
# Out:
#   Statewide lockdown orders  \
#                       State
# 0                   Alabama
# 1                    Alaska
# 2                   Arizona
# 3                  Arkansas
# 4                California
#
#                                                                     \
#                                          Order dates Link to order
# 0                                  April 4- April 30          Link
# 1  March 28 - April 27 (business can begin to reo...          Link
# 2                               March 31 - May 15[5]          Link
# 3                                               None           NaN
# 4                                     March 19 - TBD          Link
#
#
#                     Official name of order
# 0        Suspend certain public gatherings
# 1                         Shelter-in-place
# 2  Stay home, stay healthy, stay connected
# 3                                      NaN
# 4                         Shelter-in-place

# %%
df_lockdown_start_date.columns
# Out:
# MultiIndex([('Statewide lockdown orders',                  'State'),
#             ('Statewide lockdown orders',            'Order dates'),
#             ('Statewide lockdown orders',          'Link to order'),
#             ('Statewide lockdown orders', 'Official name of order')],
#            )

# %% [markdown]
# Drop mutiindex column from the dataframe

# %%
df_lockdown_start_date= df_lockdown_start_date['Statewide lockdown orders'].reset_index(drop=True)
# Out:
#         State                                        Order dates  \
# 0     Alabama                                  April 4- April 30
# 1      Alaska  March 28 - April 27 (business can begin to reo...
# 2     Arizona                               March 31 - May 15[5]
# 3    Arkansas                                               None
# 4  California                                     March 19 - TBD
#
#   Link to order                   Official name of order
# 0          Link        Suspend certain public gatherings
# 1          Link                         Shelter-in-place
# 2          Link  Stay home, stay healthy, stay connected
# 3           NaN                                      NaN
# 4          Link                         Shelter-in-place

# %%
df_lockdown_start_date
# Out:
#              State                                        Order dates  \
# 0          Alabama                                  April 4- April 30
# 1           Alaska  March 28 - April 27 (business can begin to reo...
# 2          Arizona                               March 31 - May 15[5]
# 3         Arkansas                                               None
# 4       California                                     March 19 - TBD
# 5         Colorado                             March 26 - April 26[6]
# 6      Connecticut                               March 23 - May 20[7]
# 7         Delaware                                  March 24 - May 31
# 8          Florida                                    April 2 - May 4
# 9          Georgia                              April 3 - April 30[8]
# 10          Hawaii                               March 25 - May 31[9]
# 11           Idaho                            March 25 - April 30[10]
# 12        Illinois                              March 21 - May 29[11]
# 13         Indiana                           March 24 - May 1[12][13]
# 14            Iowa                                               None
# 15          Kansas                               March 30 - May 3[14]
# 16        Kentucky                                     March 26 - TBD
# 17       Louisiana                              March 23 - May 15[15]
# 18           Maine                               April 2 - May 31[16]
# 19        Maryland                                  March 30 - May 15
# 20   Massachusetts                      March 24 - May 18[17][18][19]
# 21        Michigan                  March 24 - June 1[20][21][22][23]
# 22       Minnesota                  March 27 - May 17[24][25][26][27]
# 23     Mississippi                             April 3 - April 27[28]
# 24        Missouri                                April 6 - May 3[29]
# 25         Montana                        March 28 - April 26[30][31]
# 26        Nebraska                                               None
# 27          Nevada                                   April 1 - May 15
# 28   New Hampshire                             March 27 - June 15[32]
# 29      New Jersey                             March 21 - June 9 [33]
# 30      New Mexico                 March 24 - June 30[34][35][36][37]
# 31        New York                             March 20 - June 27[38]
# 32  North Carolina                          March 30 - May 22[39][40]
# 33    North Dakota                                               None
# 34            Ohio                      March 23 - May 19[41][42][43]
# 35        Oklahoma                                April 1 - May 6[44]
# 36          Oregon                                     March 23 - TBD
# 37    Pennsylvania                           April 1 - June 4[45][46]
# 38    Rhode Island                               March 28 - May 8[47]
# 39  South Carolina                                April 7 - May 4[48]
# 40    South Dakota                                               None
# 41       Tennessee                            March 31 - April 30[49]
# 42           Texas                                 April 2 - April 30
# 43            Utah                                               None
# 44         Vermont                              March 24 - May 15[50]
# 45        Virginia                                  March 30 - May 29
# 46      Washington                          March 24 - May 31[51][52]
# 47   West Virginia                                   March 24 - May 4
# 48       Wisconsin                          March 25 - May 13[53][54]
# 49         Wyoming                                               None
#
#    Link to order                             Official name of order
# 0           Link                  Suspend certain public gatherings
# 1           Link                                   Shelter-in-place
# 2           Link            Stay home, stay healthy, stay connected
# 3            NaN                                                NaN
# 4           Link                                   Shelter-in-place
# 5           Link                                       Stay-at-home
# 6           Link                               Stay Safe, Stay Home
# 7           Link                                       Stay-at-Home
# 8           Link                                       Stay-at-home
# 9           Link                                   Shelter-in-place
# 10          Link                                       Stay-at-home
# 11          Link                                          Stay home
# 12          Link                                       Stay-at-Home
# 13          Link                                       Stay-at-home
# 14           NaN                                                NaN
# 15          Link                                          Stay home
# 16          Link                               Stay healthy at home
# 17          Link                                       Stay-at-Home
# 18          Link                                       Stay-at-home
# 19          Link                                       Stay-at-home
# 20          Link                                       Stay-at-home
# 21          Link                               Stay Home, Stay Safe
# 22          Link                                       Stay-at-home
# 23          Link                                   Shelter-in-place
# 24          Link                                 Stay Home Missouri
# 25          Link                                       Stay-at-home
# 26           NaN                                                NaN
# 27          Link                                       Stay-at-home
# 28          Link                                   Stay-at-home 2.0
# 29          Link                                       Stay-at-home
# 30          Link                                       Stay-at-home
# 31          Link                            New York State on PAUSE
# 32          Link                                       Stay-at-home
# 33           NaN                                                NaN
# 34          Link                                       Stay-at-home
# 35          Link                                      Safer at home
# 36          Link                                       Stay-at-home
# 37          Link                                       Stay-at-home
# 38          Link                                       Stay-at-home
# 39          Link                                       Home or work
# 40           NaN                                                NaN
# 41          Link                                      Safer at home
# 42          Link  Statewide essential services and activities pr...
# 43           NaN                                                NaN
# 44          Link                                       Stay-at-home
# 45          Link                                       Stay-at-home
# 46          Link                                       Stay-at-home
# 47          Link                                       Stay-at-home
# 48          Link                                      Safer at Home
# 49           NaN                                                NaN

# %%
df_lockdown_start_date['State'].nunique()
# Out:
# 50

# %% [markdown]
# Seven states don't have lockdown dates

# %% [markdown]
# 2- import date end of lockdown from another website

# %%
website_url = 'https://www.timeanddate.com/holidays/us/last-day-of-lockdown'
response = requests.get(website_url)

response.status_code
# Out:
# 200

# %%
soup = BS(response.content, 'lxml')
print(soup.title)
# Out:
# <title>Last Day of Stay at Home Order in the United States</title>

# %%
tables = soup.find_all('table', attrs = {'class': 'tb-theme fw sep'})
#tables

# %%
len(tables)
# Out:
# 1

# %%
result_list = pd.read_html(str(tables[0]))
len(result_list)
# Out:
# 1

# %%
lockdown_end_date = result_list[0]  # get the first df from the list

lockdown_end_date.head()
# Out:
#    Year Weekday    Date                                Name  \
# 0  2020     Tue  Apr 21      Last Day of Stay at Home Order
# 1  2020     Fri  Apr 24  Last Day of Stay at Home Directive
# 2  2020     Sun  Apr 26      Last Day of Stay at Home Order
# 3  2020     Thu  Apr 30      Last Day of Stay at Home Order
# 4  2020     Thu  Apr 30      Last Day of Stay at Home Order
#
#         Holiday Type      Area
# 0  COVID-19 Lockdown    Alaska
# 1  COVID-19 Lockdown   Montana
# 2  COVID-19 Lockdown  Colorado
# 3  COVID-19 Lockdown   Alabama
# 4  COVID-19 Lockdown   Georgia

# %%
lockdown_end_date['Area'].nunique()
# Out:
# 38

# %%
df_lockdown_end_date= lockdown_end_date[['Area', 'Date']]
df_lockdown_end_date.head()
# Out:
#        Area    Date
# 0    Alaska  Apr 21
# 1   Montana  Apr 24
# 2  Colorado  Apr 26
# 3   Alabama  Apr 30
# 4   Georgia  Apr 30

# %%
df_lockdown_end_date_clean= df_lockdown_end_date.rename(columns={'Area' : 'State' , 'Date' : 'date_end'})

# %%
df_lockdown_end_date_clean.head()
# Out:
#       State date_end
# 0    Alaska   Apr 21
# 1   Montana   Apr 24
# 2  Colorado   Apr 26
# 3   Alabama   Apr 30
# 4   Georgia   Apr 30

# %% [markdown]
# merge both dataframes of date start and date end

# %%
lockdown_start_end= pd.merge (
                             df_lockdown_end_date_clean,
                             df_lockdown_start_date,
                                on = ['State'],
                                how = 'left', sort = True)

# %%
lockdown_start_end
# Out:
#                    State date_end  \
# 0                Alabama   Apr 30
# 1                 Alaska   Apr 21
# 2                Arizona   May 15
# 3               Colorado   Apr 26
# 4            Connecticut   May 20
# 5               Delaware   May 31
# 6   District of Columbia   May 29
# 7                Florida    May 3
# 8                Georgia   Apr 30
# 9                 Hawaii   May 31
# 10                 Idaho   Apr 30
# 11              Illinois   May 30
# 12               Indiana    May 3
# 13                Kansas    May 3
# 14             Louisiana   May 15
# 15         Massachusetts   May 18
# 16              Michigan    Jun 1
# 17             Minnesota   May 17
# 18           Mississippi   May 25
# 19              Missouri    May 3
# 20               Montana   Apr 24
# 21                Nevada   May 15
# 22         New Hampshire   Jun 15
# 23            New Mexico   Jun 30
# 24              New York   Jun 13
# 25        North Carolina   May 22
# 26                  Ohio   May 19
# 27              Oklahoma   Apr 30
# 28          Pennsylvania    Jun 4
# 29          Rhode Island    May 8
# 30        South Carolina    May 4
# 31             Tennessee   Apr 30
# 32                 Texas   Apr 30
# 33                  Utah    May 1
# 34               Vermont   May 15
# 35              Virginia   Jun 10
# 36            Washington   May 31
# 37             Wisconsin   May 13
#
#                                           Order dates Link to order  \
# 0                                   April 4- April 30          Link
# 1   March 28 - April 27 (business can begin to reo...          Link
# 2                                March 31 - May 15[5]          Link
# 3                              March 26 - April 26[6]          Link
# 4                                March 23 - May 20[7]          Link
# 5                                   March 24 - May 31          Link
# 6                                                 NaN           NaN
# 7                                     April 2 - May 4          Link
# 8                               April 3 - April 30[8]          Link
# 9                                March 25 - May 31[9]          Link
# 10                            March 25 - April 30[10]          Link
# 11                              March 21 - May 29[11]          Link
# 12                           March 24 - May 1[12][13]          Link
# 13                               March 30 - May 3[14]          Link
# 14                              March 23 - May 15[15]          Link
# 15                      March 24 - May 18[17][18][19]          Link
# 16                  March 24 - June 1[20][21][22][23]          Link
# 17                  March 27 - May 17[24][25][26][27]          Link
# 18                             April 3 - April 27[28]          Link
# 19                                April 6 - May 3[29]          Link
# 20                        March 28 - April 26[30][31]          Link
# 21                                   April 1 - May 15          Link
# 22                             March 27 - June 15[32]          Link
# 23                 March 24 - June 30[34][35][36][37]          Link
# 24                             March 20 - June 27[38]          Link
# 25                          March 30 - May 22[39][40]          Link
# 26                      March 23 - May 19[41][42][43]          Link
# 27                                April 1 - May 6[44]          Link
# 28                           April 1 - June 4[45][46]          Link
# 29                               March 28 - May 8[47]          Link
# 30                                April 7 - May 4[48]          Link
# 31                            March 31 - April 30[49]          Link
# 32                                 April 2 - April 30          Link
# 33                                               None           NaN
# 34                              March 24 - May 15[50]          Link
# 35                                  March 30 - May 29          Link
# 36                          March 24 - May 31[51][52]          Link
# 37                          March 25 - May 13[53][54]          Link
#
#                                Official name of order
# 0                   Suspend certain public gatherings
# 1                                    Shelter-in-place
# 2             Stay home, stay healthy, stay connected
# 3                                        Stay-at-home
# 4                                Stay Safe, Stay Home
# 5                                        Stay-at-Home
# 6                                                 NaN
# 7                                        Stay-at-home
# 8                                    Shelter-in-place
# 9                                        Stay-at-home
# 10                                          Stay home
# 11                                       Stay-at-Home
# 12                                       Stay-at-home
# 13                                          Stay home
# 14                                       Stay-at-Home
# 15                                       Stay-at-home
# 16                               Stay Home, Stay Safe
# 17                                       Stay-at-home
# 18                                   Shelter-in-place
# 19                                 Stay Home Missouri
# 20                                       Stay-at-home
# 21                                       Stay-at-home
# 22                                   Stay-at-home 2.0
# 23                                       Stay-at-home
# 24                            New York State on PAUSE
# 25                                       Stay-at-home
# 26                                       Stay-at-home
# 27                                      Safer at home
# 28                                       Stay-at-home
# 29                                       Stay-at-home
# 30                                       Home or work
# 31                                      Safer at home
# 32  Statewide essential services and activities pr...
# 33                                                NaN
# 34                                       Stay-at-home
# 35                                       Stay-at-home
# 36                                       Stay-at-home
# 37                                      Safer at Home

# %%
#save it to csv file and join it later in the join notebook
lockdown_start_end.to_csv('../data/states_lockdown_dates.csv', index= False)
